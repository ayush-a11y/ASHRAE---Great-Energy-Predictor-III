# %% [markdown]
# 1. Model - stacked_regression_lasso_ridge_lgbm

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model","RMSE","Fold"]
summary.add_row(["Stacked Regression",1.16, 0])
summary.add_row(["Stacked Regression",1.18, 1])
print(summary)
# Out:
# +--------------------+------+------+
# |       Model        | RMSE | Fold |
# +--------------------+------+------+
# | Stacked Regression | 1.16 |  0   |
# | Stacked Regression | 1.18 |  1   |
# +--------------------+------+------+

# %%
from IPython.display import Image
Image(filename='stacked_regressor2.PNG')

# %% [markdown]
# 2. Model - hierarchical_bayesian_target_encoding

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model", "RMSE", "Meter-wise"]
summary.add_row(["bayesian-target-encoding",.785, "Meter-0"])
summary.add_row(["bayesian-target-encoding",1.34, "Meter-1"])
summary.add_row(["bayesian-target-encoding",1.44, "Meter-2"])
summary.add_row(["bayesian-target-encoding",1.43, "Meter-3"])
summary.add_row(["bayesian-target-encoding",1.43, "Overall"])
print(summary)
# Out:
# +--------------------------+-------+------------+
# |          Model           |  RMSE | Meter-wise |
# +--------------------------+-------+------------+
# | bayesian-target-encoding | 0.785 |  Meter-0   |
# | bayesian-target-encoding |  1.34 |  Meter-1   |
# | bayesian-target-encoding |  1.44 |  Meter-2   |
# | bayesian-target-encoding |  1.43 |  Meter-3   |
# | bayesian-target-encoding |  1.43 |  Overall   |
# +--------------------------+-------+------------+

# %%
from IPython.display import Image
Image(filename='/content/Bayesian Encoding 2.PNG')

# %% [markdown]
# 3. Model - RF_GBDT_DT_MODELS with no kfold

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model","RMSE"]
summary.add_row(["LightGBM RF",1.68])
summary.add_row(["LightGBM GBDT",1.11])
summary.add_row(["DT",1.45])
print(summary)
# Out:
# +---------------+------+
# |     Model     | RMSE |
# +---------------+------+
# |  LightGBM RF  | 1.68 |
# | LightGBM GBDT | 1.11 |
# |       DT      | 1.45 |
# +---------------+------+

# %%
from IPython.display import Image
Image(filename='/content/RF_GBDT_DT_MODELS.PNG')

# %% [markdown]
# 4. Dense NN Model with 2 Folds

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model", "RMSE"]
summary.add_row(["Demse NN",.57432])
print(summary)
# Out:
# +----------+---------+
# |  Model   |   RMSE  |
# +----------+---------+
# | Demse NN | 0.57432 |
# +----------+---------+

# %%
from IPython.display import Image
Image(filename='DENSE NN1.PNG')

# %% [markdown]
# 5. LightGBM GBDT with 3 Folds

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model", "RMSE"]
summary.add_row(["LightGBM GBDT",.646105])
print(summary)
# Out:
# +---------------+----------+
# |     Model     |   RMSE   |
# +---------------+----------+
# | LightGBM GBDT | 0.646105 |
# +---------------+----------+

# %%
from IPython.display import Image
Image(filename='LGBM1.PNG')

# %% [markdown]
# 6. Model - Custom stacked Rgeressor

# %%
from prettytable import PrettyTable
summary = PrettyTable()


summary.field_names = ["Model","RMSE"]
summary.add_row(["Custom_Stacked_Regression",1.12])

print(summary)
# Out:
# +---------------------------+------+
# |           Model           | RMSE |
# +---------------------------+------+
# | Custom_Stacked_Regression | 1.12 |
# +---------------------------+------+

# %%
from IPython.display import Image
Image(filename='/content/custom_stacked_regressor.PNG')

# %% [markdown]
# 7. Model - Ensemble Model - Stacked_Regresor + Bayesian Target Encoding

# %%
from IPython.display import Image
Image(filename='/content/ensemble3.PNG')
